# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoleVigilant/NicoleVigilant-DataScience-2025/blob/main/Completed/05-Foundations/04-data_input_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 04 - Data Input and Output
#
# Most of data science is about **loading data, exploring it, and saving results**.
# In this notebook you will learn:
# - Reading CSV files with Pandas
# - Inspecting DataFrames (`head`, `info`, `describe`)
# - Writing data back to CSV
# - Reading Excel files (if available)

# %% [markdown]
# ## 1. Reading CSV Files

# %%
import pandas as pd

# Create a small CSV for demo
data = """Name,Age,Score
Alice,23,90
Bob,25,85
Charlie,22,95
"""
with open("students.csv", "w") as f:
    f.write(data)

# Read CSV into DataFrame
df = pd.read_csv("students.csv")
df
# Out:
#       Name  Age  Score
# 0    Alice   23     90
# 1      Bob   25     85
# 2  Charlie   22     95

# %% [markdown]
# ✅ **Your Turn**: Create your own small CSV (3–5 rows) and read it into Pandas.

# %%
import pandas as pd

data = """Name,Age,Score
Nicole,24,100
Beyonce,20,95
Amy,21,70
"""
with open("students1.csv", "w") as f:
    f.write(data)
df = pd.read_csv("students1.csv")
df
# Out:
#       Name  Age  Score
# 0   Nicole   24    100
# 1  Beyonce   20     95
# 2      Amy   21     70

# %% [markdown]
# ## 2. Exploring DataFrames

# %%
# Look at the first rows
df.head()
# Out:
#       Name  Age  Score
# 0    Alice   23     90
# 1      Bob   25     85
# 2  Charlie   22     95

# %%
# Info about columns and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Score   3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
# Summary statistics
df.describe()
# Out:
#              Age  Score
# count   3.000000    3.0
# mean   23.333333   90.0
# std     1.527525    5.0
# min    22.000000   85.0
# 25%    22.500000   87.5
# 50%    23.000000   90.0
# 75%    24.000000   92.5
# max    25.000000   95.0

# %% [markdown]
# ✅ **Your Turn**: Use `.head()` to preview your dataset and `.describe()` to see basic statistics.

# %%
df.head()
# Out:
#       Name  Age  Score
# 0   Nicole   24    100
# 1  Beyonce   20     95
# 2      Amy   21     70

# %%
df.describe()
# Out:
#              Age       Score
# count   3.000000    3.000000
# mean   21.666667   88.333333
# std     2.081666   16.072751
# min    20.000000   70.000000
# 25%    20.500000   82.500000
# 50%    21.000000   95.000000
# 75%    22.500000   97.500000
# max    24.000000  100.000000

# %% [markdown]
# ## 3. Writing CSV Files

# %%
# Save the DataFrame to a new CSV
df.to_csv("students_copy.csv", index=False)
# %ls *.csv
# Out:
# students_copy.csv  students.csv

# %% [markdown]
# ✅ **Your Turn**: Save your DataFrame to a CSV file called `my_data.csv`.

# %%
df.to_csv("my_data.csv", index=False)
# %ls *.csv
# Out:
# my_data.csv  students1.csv  students_copy.csv  students.csv

# %% [markdown]
# ## 4. Reading Excel Files

# %%
# Optional: Requires 'openpyxl' installed
# Save to Excel
df.to_excel("students.xlsx", index=False)

# Read Excel file
pd.read_excel("students.xlsx")
# Out:
#       Name  Age  Score
# 0    Alice   23     90
# 1      Bob   25     85
# 2  Charlie   22     95

# %% [markdown]
# ✅ **Your Turn**: Try saving your dataset to Excel and reading it back (if supported in your environment).

# %%
df.to_excel("my_data.xlsx", index=False)

pd.read_excel("my_data.xlsx")
# Out:
#       Name  Age  Score
# 0   Nicole   24    100
# 1  Beyonce   20     95
# 2      Amy   21     70

# %% [markdown]
# ---
# ### Summary
# - `pd.read_csv` loads data into a DataFrame.
# - Use `.head()`, `.info()`, `.describe()` to explore quickly.
# - `df.to_csv` and `df.to_excel` save results.
# - Pandas makes file I/O simple and reliable.
